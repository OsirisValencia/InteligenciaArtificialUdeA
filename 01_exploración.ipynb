# %% [markdown]
# <a href="https://colab.research.google.com/github/OsirisValencia/InteligenciaArtificialUdeA/blob/main/01_exploraci%C3%B3n.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
os.environ['KAGGLE_CONFIG_DIR'] = '.'
# !kaggle
# !chmod 600 ./kaggle.json
# Out:
# usage: kaggle [-h] [-v] [-W] {competitions,c,datasets,d,kernels,k,models,m,files,f,config} ...
# kaggle: error: the following arguments are required: command

# %%
# !kaggle competitions download -c udea-ai-4-eng-20251-pruebas-saber-pro-colombia
# !unzip udea-ai-4-eng-20251-pruebas-saber-pro-colombia.zip
# Out:
# Archive:  udea-ai-4-eng-20251-pruebas-saber-pro-colombia.zip
#   inflating: submission_example.csv
#   inflating: test.csv
#   inflating: train.csv

# %%
import pandas as pd
import numpy as np

# cargar
train_df = pd.read_csv('train.csv')

# información
print(train_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 692500 entries, 0 to 692499
# Data columns (total 21 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   ID                              692500 non-null  int64
#  1   PERIODO                         692500 non-null  int64
#  2   ESTU_PRGM_ACADEMICO             692500 non-null  object
#  3   ESTU_PRGM_DEPARTAMENTO          692500 non-null  object
#  4   ESTU_VALORMATRICULAUNIVERSIDAD  686213 non-null  object
#  5   ESTU_HORASSEMANATRABAJA         661643 non-null  object
#  6   FAMI_ESTRATOVIVIENDA            660363 non-null  object
#  7   FAMI_TIENEINTERNET              665871 non-null  object
#  8   FAMI_EDUCACIONPADRE             669322 non-null  object
#  9   FAMI_TIENELAVADORA              652727 non-null  object
#  10  FAMI_TIENEAUTOMOVIL             648877 non-null  object
#  11  ESTU_PRIVADO_LIBERTAD           692500 non-null  object
# ...

# %%
# Primeras columnas
train_df.head(20).T
# Out:
#                                                                       0   \
# ID                                                                904256
# PERIODO                                                            20212
# ESTU_PRGM_ACADEMICO                                           ENFERMERIA
# ESTU_PRGM_DEPARTAMENTO                                            BOGOTÁ
# ESTU_VALORMATRICULAUNIVERSIDAD  Entre 5.5 millones y menos de 7 millones
# ESTU_HORASSEMANATRABAJA                                Menos de 10 horas
# FAMI_ESTRATOVIVIENDA                                           Estrato 3
# FAMI_TIENEINTERNET                                                    Si
# FAMI_EDUCACIONPADRE                     Técnica o tecnológica incompleta
# FAMI_TIENELAVADORA                                                    Si
# FAMI_TIENEAUTOMOVIL                                                   Si
# ESTU_PRIVADO_LIBERTAD                                                  N
# ...

# %%
# Valores faltantes.
print(train_df.isnull().sum().pipe(lambda x: x[x > 0]))
# Out:
# ESTU_VALORMATRICULAUNIVERSIDAD     6287
# ESTU_HORASSEMANATRABAJA           30857
# FAMI_ESTRATOVIVIENDA              32137
# FAMI_TIENEINTERNET                26629
# FAMI_EDUCACIONPADRE               23178
# FAMI_TIENELAVADORA                39773
# FAMI_TIENEAUTOMOVIL               43623
# ESTU_PAGOMATRICULAPROPIO           6498
# FAMI_TIENECOMPUTADOR              38103
# FAMI_TIENEINTERNET.1              26629
# FAMI_EDUCACIONMADRE               23664
# dtype: int64

# %%
# Descripción sobre los datos númericos.
print(train_df.describe())
# Out:
#                   ID        PERIODO         coef_1         coef_2  \
# count  692500.000000  692500.000000  692500.000000  692500.000000
# mean   494606.130576   20198.366679       0.268629       0.259996
# std    285585.209455      10.535037       0.122130       0.093480
# min         1.000000   20183.000000       0.000000       0.000000
# 25%    247324.750000   20195.000000       0.203000       0.212000
# 50%    494564.500000   20195.000000       0.240000       0.271000
# 75%    741782.500000   20203.000000       0.314000       0.309000
# max    989286.000000   20213.000000       0.657000       0.487000
#
#               coef_3         coef_4
# count  692500.000000  692500.000000
# mean        0.262087       0.262903
# std         0.058862       0.067944
# min         0.000000       0.000000
# 25%         0.254000       0.255000
# 50%         0.276000       0.285000
# 75%         0.293000       0.303000
# max         0.320000       0.332000

# %%
pd.DataFrame({'Columna': train_df.columns, 'Valores Distintos': [train_df[col].nunique() for col in train_df.columns]})
# Out:
#                            Columna  Valores Distintos
# 0                               ID             692500
# 1                          PERIODO                  9
# 2              ESTU_PRGM_ACADEMICO                948
# 3           ESTU_PRGM_DEPARTAMENTO                 31
# 4   ESTU_VALORMATRICULAUNIVERSIDAD                  8
# 5          ESTU_HORASSEMANATRABAJA                  5
# 6             FAMI_ESTRATOVIVIENDA                  7
# 7               FAMI_TIENEINTERNET                  2
# 8              FAMI_EDUCACIONPADRE                 12
# 9               FAMI_TIENELAVADORA                  2
# 10             FAMI_TIENEAUTOMOVIL                  2
# 11           ESTU_PRIVADO_LIBERTAD                  2
# 12        ESTU_PAGOMATRICULAPROPIO                  2
# 13            FAMI_TIENECOMPUTADOR                  2
# 14            FAMI_TIENEINTERNET.1                  2
# 15             FAMI_EDUCACIONMADRE                 12
# ...

# %%
{col: train_df[col].value_counts(dropna=False).to_dict() for col in train_df.columns if train_df[col].nunique() < 10}

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Asumiendo que tienes un DataFrame llamado 'df'
def visualizar_columnas_con_pocos_valores(dataframe, max_valores=12):
    # Identificar columnas con menos de max_valores valores únicos
    columnas_filtradas = [col for col in dataframe.columns if dataframe[col].nunique() < max_valores]

    if not columnas_filtradas:
        print(f"No hay columnas con menos de {max_valores} valores únicos.")
        return

    print(f"Se encontraron {len(columnas_filtradas)} columnas con menos de {max_valores} valores únicos.\n")

    # Para cada columna, crear una visualización
    for i, columna in enumerate(columnas_filtradas):
        # Obtener conteo de valores
        conteo = dataframe[columna].value_counts(dropna=False)

        df_conteo = pd.DataFrame({
            'Valor': conteo.index.astype(str),
            'Cantidad': conteo.values,
            'Porcentaje': (conteo.values / len(dataframe) * 100).round(2)

        })

        # Ordenar por cantidad (mayor a menor)
        df_conteo = df_conteo.sort_values('Cantidad', ascending=False).reset_index(drop=True)

        # Imprimir tabla de distribución
        print(f"\n--- Columna: {columna} ({conteo.count()} valores únicos) ---")
        print(df_conteo.to_string(index=False))


# Ejemplo de uso
visualizar_columnas_con_pocos_valores(train_df)
# Out:
# Se encontraron 12 columnas con menos de 12 valores únicos.
#
#
# --- Columna: PERIODO (9 valores únicos) ---
# Valor  Cantidad  Porcentaje
# 20195    180873       26.12
# 20203    171838       24.81
# 20212    171412       24.75
# 20183    164818       23.80
# 20194      1472        0.21
# 20213      1178        0.17
# 20202       490        0.07
# 20184       254        0.04
# 20196       165        0.02
#
# --- Columna: ESTU_VALORMATRICULAUNIVERSIDAD (9 valores únicos) ---
#                                    Valor  Cantidad  Porcentaje
#   Entre 1 millón y menos de 2.5 millones    204048       29.47
# Entre 2.5 millones y menos de 4 millones    127430       18.40
#                         Menos de 500 mil     80263       11.59
#        Entre 500 mil y menos de 1 millón     78704       11.37
# Entre 4 millones y menos de 5.5 millones     69736       10.07
#                        Más de 7 millones     68014        9.82
# ...
